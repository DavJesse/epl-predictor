# %%
# Load the PROCESSED data (not raw)
df_processed = pd.read_csv('../data/processed/epl_training_data.csv')

# Look at a specific game to sanity check
# Let's check a random game late in the season to see if stats accumulated
print(df_processed[['Date', 'HomeTeam', 'AwayTeam', 'Home_Points_Avg', 'Away_Points_Avg']].tail())
# Out:
#             Date   HomeTeam    AwayTeam  Home_Points_Avg  Away_Points_Avg
# 1895  2024-05-19  Brentford   Newcastle              2.0              1.4
# 1896  2024-05-19    Arsenal     Everton              3.0              2.6
# 1897  2024-05-19   Man City    West Ham              3.0              0.8
# 1898  2024-05-19   Brighton  Man United              0.8              1.4
# 1899  2024-05-19      Luton      Fulham              0.2              1.0
